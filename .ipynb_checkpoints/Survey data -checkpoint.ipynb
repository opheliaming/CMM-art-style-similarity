# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('data/CCM Art Style Similarity_April 28, 2022_14.59.csv')

# %%
data = data[data['Status'] == '0']   # filter only true responses

# %%
data.shape
# Out:
# (26, 168)

# %%
data.head()
# Out:
#               StartDate              EndDate Status       IPAddress Progress  \
# 7   2022-04-22 12:07:41  2022-04-22 12:27:56      0   50.225.16.155      100
# 8   2022-04-22 12:23:09  2022-04-22 12:33:59      0  173.68.101.249      100
# 9   2022-04-22 12:07:57  2022-04-22 12:40:34      0  185.113.80.111      100
# 10  2022-04-22 12:17:51  2022-04-22 12:45:43      0  24.102.120.157      100
# 11  2022-04-22 13:36:08  2022-04-22 13:56:30      0  143.177.74.193      100
#
#    Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 7                   1214        1  2022-04-22 12:27:57  R_AA03VLmsvUEcVMt
# 8                    650        1  2022-04-22 12:34:00  R_10IyRRECXYIYv6z
# 9                   1956        1  2022-04-22 12:40:34  R_3Rkn5l6BuUT1wRi
# 10                  1671        1  2022-04-22 12:45:43  R_3KImNmtbcSKvvqC
# 11                  1222        1  2022-04-22 13:56:31  R_3HIi3rqxWAiZyGq
#
#    RecipientLastName  ... 48_similarity_gen 48_similarity_style  \
# 7                NaN  ...                 6                   1
# 8                NaN  ...                 9                   3
# 9                NaN  ...                 7                   3
# 10               NaN  ...                 6                   5
# 11               NaN  ...                 7                   1
#
#    48_similarity_subject                                    1_visual_expl_1  \
# 7                      8  Lots of greenish-yellowish colors. Since pictu...
# 8                      8                              color, strokes, scene
# 9                      7  I gave a score larger than 2 because both imag...
# 10                     8  Both are landscape images. It looks like the l...
# 11                     7                                    Just a feeling
#
#                                        1_style_expl_1  \
# 7   Both styles are diverging from classical reali...
# 8   changes colors a lot, uses similar brush strok...
# 9   I gave a score less than 4 because the left on...
# 10  Both images have some angularity and have sect...
# 11                                     Just. Feeling
#
#                                       1_visual_expl_2  \
# 7   Both images show a small town, the composition...
# 8                  very similar scene and perspective
# 9   I gave a score larger than 4 because both imag...
# 10             Both are scenes of towns, buildings.
# 11                                             Houses
#
#                                        1_style_expl_2 age art_training_years  \
# 7   Left one gives an impression of old monumental...  23                  0
# 8   right one is much more colorful, left one has ...  24                  0
# 9   I gave a score larger than 4 because both feel...  29                  0
# 10                  Both have irregular definitions.   61                  0
# 11                                          Abstract   41                  0
#
#    art_training_type
# 7                  5
# 8                  6
# 9                  6
# 10                 6
# 11                 6
#
# [5 rows x 168 columns]

# %%
list(data.columns)
# Out:
# ['StartDate',
#  'EndDate',
#  'Status',
#  'IPAddress',
#  'Progress',
#  'Duration (in seconds)',
#  'Finished',
#  'RecordedDate',
#  'ResponseId',
#  'RecipientLastName',
#  'RecipientFirstName',
#  'RecipientEmail',
#  'ExternalReference',
#  'LocationLatitude',
#  'LocationLongitude',
#  'DistributionChannel',
#  'UserLanguage',
#  '1_similarity_gen',
#  '1_similarity_style',
#  '1_similarity_subject',
#  '2_similarity_gen',
#  '2_similarity_style',
#  '2_similarity_subject',
#  '3_similarity_gen',
#  '3_similarity_style',
#  '3_similarity_subject',
#  '4_similarity_gen',
#  '4_similarity_style',
#  '4_similarity_subject',
#  '5_similarity_gen',
#  '5_similarity_style',
#  '5_similarity_subject',
#  '6_similarity_gen',
#  '6_similarity_style',
#  '6_similarity_subject',
#  '7_similarity_gen',
#  '7_similarity_style',
#  '7_similarity_subject',
#  '8_similarity_gen',
#  '8_similarity_style',
#  '8_similarity_subject',
#  '9_similarity_gen',
#  '9_similarity_style',
#  '9_similarity_subject',
#  '10_similarity_gen',
#  '10_similarity_style',
#  '10_similarity_subject',
#  '11_similarity_gen',
#  '11_similarity_style',
#  '11_similarity_subject',
#  '12_similarity_gen',
#  '12_similarity_style',
#  '12_similarity_subject',
#  '13_similarity_gen',
#  '13_similarity_style',
#  '13_similarity_subject',
#  '14_similarity_gen',
#  '14_similarity_style',
#  '14_similarity_subject',
#  '15_similarity_gen',
#  '15_similarity_style',
#  '15_similarity_subject',
#  '16_similarity_gen',
#  '16_similarity_style',
#  '16_similarity_subject',
#  '17_similarity_gen',
#  '17_similarity_style',
#  '17_similarity_subject',
#  '18_similarity_gen',
#  '18_similarity_style',
#  '18_similarity_subject',
#  '19_similarity_gen',
#  '19_similarity_style',
#  '19_similarity_subject',
#  '20_similarity_gen',
#  '20_similarity_style',
#  '20_similarity_subject',
#  '21_similarity_gen',
#  '21_similarity_style',
#  '21_similarity_subject',
#  '22_similarity_gen',
#  '22_similarity_style',
#  '22_similarity_subject',
#  '23_similarity_gen',
#  '23_similarity_style',
#  '23_similarity_subject',
#  '24_similarity_gen',
#  '24_similarity_style',
#  '24_similarity_subject',
#  '25_similarity_gen',
#  '25_similarity_style',
#  '25_similarity_subject',
#  '26_similarity_gen',
#  '26_similarity_style',
#  '26_similarity_subject',
#  '27_similarity_gen',
#  '27_similarity_style',
#  '27_similarity_subject',
#  '28_similarity_gen',
#  '28_similarity_style',
#  '28_similarity_subject',
#  '29_similarity_gen',
#  '29_similarity_style',
#  '29_similarity_subject',
#  '30_similarity_gen',
#  '30_similarity_style',
#  '30_similarity_subject',
#  '31_similarity_gen',
#  '31_similarity_style',
#  '31_similarity_subject',
#  '32_similarity_gen',
#  '32_similarity_style',
#  '32_similarity_subject',
#  '33_similarity_gen',
#  '33_similarity_style',
#  '33_similarity_subject',
#  '34_similarity_gen',
#  '34_similarity_style',
#  '34_similarity_subject',
#  '35_similarity_gen',
#  '35_similarity_style',
#  '35_similarity_subject',
#  '36_similarity_gen',
#  '36_similarity_style',
#  '36_similarity_subject',
#  '37_similarity_gen',
#  '37_similarity_style',
#  '37_similarity_subject',
#  '38_similarity_gen',
#  '38_similarity_style',
#  '38_similarity_subject',
#  '39_similarity_gen',
#  '39_similarity_style',
#  '39_similarity_subject',
#  '40_similarity_gen',
#  '40_similarity_style',
#  '40_similarity_subject',
#  '41_similarity_gen',
#  '41_similarity_style',
#  '41_similarity_subject',
#  '42_similarity_gen',
#  '42_similarity_style',
#  '42_similarity_subject',
#  '43_similarity_gen',
#  '43_similarity_style',
#  '43_similarity_subject',
#  '44_similarity_gen',
#  '44_similarity_style',
#  '44_similarity_subject',
#  '45_similarity_gen',
#  '45_similarity_style',
#  '45_similarity_subject',
#  '46_similarity_gen',
#  '46_similarity_style',
#  '46_similarity_subject',
#  '47_similarity_gen',
#  '47_similarity_style',
#  '47_similarity_subject',
#  '48_similarity_gen',
#  '48_similarity_style',
#  '48_similarity_subject',
#  '1_visual_expl_1',
#  '1_style_expl_1',
#  '1_visual_expl_2',
#  '1_style_expl_2',
#  'age',
#  'art_training_years',
#  'art_training_type']

# %%
# remove unwanted columns
unwanted = ['StartDate','EndDate','Status','IPAddress','Progress','Finished','RecordedDate','ResponseId',
            'RecipientLastName','RecipientFirstName','RecipientEmail','ExternalReference','LocationLatitude','LocationLongitude',
            'DistributionChannel','UserLanguage']

# %%
 data = data[data.columns[~data.columns.isin(unwanted)]]

# %%
data.dtypes
# Out:
# Duration (in seconds)    object
# 1_similarity_gen         object
# 1_similarity_style       object
# 1_similarity_subject     object
# 2_similarity_gen         object
#                           ...
# 1_visual_expl_2          object
# 1_style_expl_2           object
# age                      object
# art_training_years       object
# art_training_type        object
# Length: 152, dtype: object

# %%
#list(data.columns)

# %%
open_end_question = ['1_visual_expl_1','1_style_expl_1','1_visual_expl_2','1_style_expl_2','art_training_type']

# %%
numeric_columns = list(set(data.columns).difference(open_end_question))

# %%
data[numeric_columns] = data[numeric_columns].astype('int32')

# %%
# demographic 
sns.distplot(data.age)
# Out:
# /Users/opheliaming/opt/anaconda3/envs/py38/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
data.describe()
# Out:
#        Duration (in seconds)  1_similarity_gen  1_similarity_style  \
# count              26.000000         26.000000           26.000000
# mean             1751.269231          3.538462            4.538462
# std              1350.379608          2.716332            2.370329
# min               632.000000          1.000000            1.000000
# 25%              1072.750000          1.000000            2.250000
# 50%              1304.000000          2.000000            5.500000
# 75%              1965.000000          6.000000            6.000000
# max              7259.000000          9.000000            8.000000
#
#        1_similarity_subject  2_similarity_gen  2_similarity_style  \
# count             26.000000         26.000000           26.000000
# mean               1.115385          4.576923            3.884615
# std                0.431455          3.360632            2.388756
# min                1.000000          1.000000            1.000000
# 25%                1.000000          1.250000            1.250000
# 50%                1.000000          4.000000            4.000000
# 75%                1.000000          7.000000            6.000000
# max                3.000000         10.000000            8.000000
#
#        2_similarity_subject  3_similarity_gen  3_similarity_style  \
# count             26.000000         26.000000           26.000000
# mean               2.000000          4.769231            3.961538
# std                1.624808          2.997435            2.125667
# min                1.000000          1.000000            1.000000
# 25%                1.000000          1.250000            2.000000
# 50%                1.000000          6.000000            4.000000
# 75%                2.000000          7.000000            5.750000
# max                6.000000         11.000000            8.000000
#
#        3_similarity_subject  ...  46_similarity_style  46_similarity_subject  \
# count             26.000000  ...            26.000000              26.000000
# mean               2.153846  ...             3.846154               6.115385
# std                1.759371  ...             2.394866               1.904246
# min                1.000000  ...             1.000000               1.000000
# 25%                1.000000  ...             2.000000               6.000000
# 50%                1.500000  ...             3.000000               6.500000
# 75%                2.750000  ...             6.000000               7.000000
# max                8.000000  ...             8.000000               8.000000
#
#        47_similarity_gen  47_similarity_style  47_similarity_subject  \
# count          26.000000            26.000000              26.000000
# mean            5.884615             5.423077               5.153846
# std             2.818892             1.814896               2.394866
# min             1.000000             1.000000               1.000000
# 25%             6.000000             5.000000               3.000000
# 50%             6.000000             6.000000               6.000000
# 75%             7.000000             6.750000               7.000000
# max            10.000000             8.000000               8.000000
#
#        48_similarity_gen  48_similarity_style  48_similarity_subject  \
# count          26.000000            26.000000              26.000000
# mean            5.653846             1.923077               7.576923
# std             3.309892             1.197433               1.390628
# min             1.000000             1.000000               1.000000
# 25%             2.000000             1.000000               8.000000
# 50%             6.000000             1.500000               8.000000
# 75%             9.000000             2.750000               8.000000
# max            10.000000             5.000000               8.000000
#
#              age  art_training_years
# count  26.000000           26.000000
# mean   29.884615            0.769231
# std     9.352334            2.103477
# min    23.000000            0.000000
# 25%    25.000000            0.000000
# 50%    27.000000            0.000000
# 75%    29.750000            0.000000
# max    61.000000           10.000000
#
# [8 rows x 147 columns]

# %%
DF_score = pd.DataFrame({'mean': data.iloc[:, 1:145].mean(axis=0), 'medium': data.iloc[:, 1:145].median(axis=0), 'min': data.iloc[:, 1:145].min(axis=0),'max': data.iloc[:, 1:145].max(axis=0)},
                       index = data.iloc[:, 1:145].columns)

# %%
DF_score
# Out:
#                            mean  medium  min  max
# 1_similarity_gen       3.538462     2.0    1    9
# 1_similarity_style     4.538462     5.5    1    8
# 1_similarity_subject   1.115385     1.0    1    3
# 2_similarity_gen       4.576923     4.0    1   10
# 2_similarity_style     3.884615     4.0    1    8
# 2_similarity_subject   2.000000     1.0    1    6
# 3_similarity_gen       4.769231     6.0    1   11
# 3_similarity_style     3.961538     4.0    1    8
# 3_similarity_subject   2.153846     1.5    1    8
# 4_similarity_gen       4.000000     4.0    1    9
# 4_similarity_style     3.961538     4.0    1    8
# 4_similarity_subject   3.384615     3.0    1    6
# 5_similarity_gen       5.807692     6.0    1   10
# 5_similarity_style     3.961538     3.0    1    7
# 5_similarity_subject   5.269231     6.0    1    8
# 6_similarity_gen       1.384615     1.0    1    6
# 6_similarity_style     1.538462     1.0    1    5
# 6_similarity_subject   1.115385     1.0    1    2
# 7_similarity_gen       2.153846     1.0    1    7
# 7_similarity_style     1.576923     1.0    1    7
# 7_similarity_subject   1.307692     1.0    1    6
# 8_similarity_gen       4.230769     4.0    1   10
# 8_similarity_style     4.576923     5.0    1    8
# 8_similarity_subject   1.653846     1.0    1    8
# 9_similarity_gen       2.307692     1.0    1    7
# 9_similarity_style     2.192308     1.5    1    7
# 9_similarity_subject   1.576923     1.0    1    7
# 10_similarity_gen      2.538462     2.0    1    7
# 10_similarity_style    2.115385     1.5    1    6
# 10_similarity_subject  1.307692     1.0    1    3
# 11_similarity_gen      4.884615     6.0    1    9
# 11_similarity_style    2.538462     2.0    1    6
# 11_similarity_subject  2.000000     2.0    1    5
# 12_similarity_gen      3.461538     2.0    1    9
# 12_similarity_style    3.384615     3.0    1    7
# 12_similarity_subject  1.307692     1.0    1    3
# 13_similarity_gen      3.692308     2.0    1   11
# 13_similarity_style    2.692308     2.0    1    7
# 13_similarity_subject  5.115385     6.0    1    8
# 14_similarity_gen      4.346154     4.0    1    9
# 14_similarity_style    4.730769     5.5    1    8
# 14_similarity_subject  1.615385     1.0    1    5
# 15_similarity_gen      2.384615     1.0    1    9
# 15_similarity_style    3.038462     2.0    1    8
# 15_similarity_subject  1.269231     1.0    1    3
# 16_similarity_gen      6.038462     6.0    1   11
# 16_similarity_style    4.807692     5.0    1    8
# 16_similarity_subject  2.000000     1.0    1    7
# 17_similarity_gen      4.000000     2.0    1    9
# 17_similarity_style    5.269231     6.0    1    8
# 17_similarity_subject  1.423077     1.0    1    3
# 18_similarity_gen      5.692308     7.0    1   10
# 18_similarity_style    5.153846     5.5    1    8
# 18_similarity_subject  2.076923     2.0    1    6
# 19_similarity_gen      5.153846     6.0    1   11
# 19_similarity_style    5.230769     6.0    1    8
# 19_similarity_subject  1.807692     1.0    1    6
# 20_similarity_gen      5.384615     6.5    1   10
# 20_similarity_style    6.846154     7.0    1    8
# 20_similarity_subject  1.384615     1.0    1    3
# 21_similarity_gen      3.653846     2.0    1    9
# 21_similarity_style    5.076923     5.5    1    8
# 21_similarity_subject  1.846154     1.0    1    7
# 22_similarity_gen      3.730769     2.0    1    9
# 22_similarity_style    3.346154     3.0    1    6
# 22_similarity_subject  1.769231     1.0    1    5
# 23_similarity_gen      5.423077     6.0    1   10
# 23_similarity_style    5.076923     5.0    1    8
# 23_similarity_subject  2.769231     2.5    1    6
# 24_similarity_gen      2.807692     1.0    1    9
# 24_similarity_style    2.346154     1.0    1    7
# 24_similarity_subject  1.884615     1.0    1    8
# 25_similarity_gen      4.423077     2.0    1   10
# 25_similarity_style    2.038462     1.0    1    7
# 25_similarity_subject  6.884615     7.0    3    8
# 26_similarity_gen      7.692308     9.0    1   11
# 26_similarity_style    4.346154     5.0    1    8
# 26_similarity_subject  7.346154     8.0    5    8
# 27_similarity_gen      8.423077     9.0    1   11
# 27_similarity_style    5.846154     6.0    1    8
# 27_similarity_subject  7.307692     8.0    5    8
# 28_similarity_gen      7.576923     9.0    1   10
# 28_similarity_style    5.538462     6.0    1    8
# 28_similarity_subject  6.423077     7.0    1    8
# 29_similarity_gen      7.230769     9.0    1   11
# 29_similarity_style    5.653846     6.0    1    8
# 29_similarity_subject  6.192308     7.0    1    8
# 30_similarity_gen      6.230769     6.5    1   11
# 30_similarity_style    3.730769     3.0    1    8
# 30_similarity_subject  5.807692     6.0    1    8
# 31_similarity_gen      5.115385     6.0    1   10
# 31_similarity_style    3.038462     2.5    1    7
# 31_similarity_subject  4.653846     6.0    1    8
# 32_similarity_gen      8.769231    10.0    1   11
# 32_similarity_style    5.846154     7.0    1    8
# 32_similarity_subject  6.923077     8.0    1    8
# 33_similarity_gen      7.384615     9.0    1   11
# 33_similarity_style    4.384615     5.0    1    8
# 33_similarity_subject  6.961538     7.0    2    8
# 34_similarity_gen      6.846154     7.0    1   11
# 34_similarity_style    4.038462     5.0    1    8
# 34_similarity_subject  7.423077     8.0    5    8
# 35_similarity_gen      6.538462     6.5    1   10
# 35_similarity_style    3.461538     3.0    1    7
# 35_similarity_subject  5.769231     7.0    1    8
# 36_similarity_gen      3.423077     2.0    1   10
# 36_similarity_style    2.461538     2.0    1    7
# 36_similarity_subject  4.384615     5.0    1    8
# 37_similarity_gen      8.615385     9.0    6   11
# 37_similarity_style    4.538462     5.5    1    8
# 37_similarity_subject  7.307692     8.0    5    8
# 38_similarity_gen      7.692308     9.0    1   11
# 38_similarity_style    4.576923     5.5    1    7
# 38_similarity_subject  6.653846     7.0    3    8
# 39_similarity_gen      6.923077     7.0    1   11
# 39_similarity_style    4.192308     3.0    1    8
# 39_similarity_subject  6.961538     7.5    2    8
# 40_similarity_gen      4.076923     2.0    1   10
# 40_similarity_style    1.115385     1.0    1    2
# 40_similarity_subject  6.423077     7.0    1    8
# 41_similarity_gen      4.423077     4.0    1   10
# 41_similarity_style    2.730769     2.5    1    6
# 41_similarity_subject  5.615385     6.0    1    8
# 42_similarity_gen      6.961538     9.0    1   11
# 42_similarity_style    3.653846     3.0    1    8
# 42_similarity_subject  6.500000     7.0    3    8
# 43_similarity_gen      3.307692     2.0    1    9
# 43_similarity_style    1.461538     1.0    1    3
# 43_similarity_subject  5.692308     6.0    1    8
# 44_similarity_gen      4.115385     2.0    1   10
# 44_similarity_style    1.115385     1.0    1    3
# 44_similarity_subject  7.192308     8.0    1    8
# 45_similarity_gen      4.730769     6.0    1    9
# 45_similarity_style    1.923077     2.0    1    5
# 45_similarity_subject  6.846154     7.0    3    8
# 46_similarity_gen      6.730769     8.0    1   10
# 46_similarity_style    3.846154     3.0    1    8
# 46_similarity_subject  6.115385     6.5    1    8
# 47_similarity_gen      5.884615     6.0    1   10
# 47_similarity_style    5.423077     6.0    1    8
# 47_similarity_subject  5.153846     6.0    1    8
# 48_similarity_gen      5.653846     6.0    1   10
# 48_similarity_style    1.923077     1.5    1    5
# 48_similarity_subject  7.576923     8.0    1    8
